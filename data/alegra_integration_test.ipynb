# %% [markdown]
# # Alegra API Integration Test

# %%
from  alegra_integration import search_item_by_name

product_name = 'PISTOLA DE SILICONA 4" X 1/2" TRUPER'
infos_product = search_item_by_name(product_name)
